# %%
from langchain_huggingface import HuggingFaceEndpoint
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

huggingfacehub_api_token = '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'

template = """
Summarize the chat based on the following chat input: {context}

Keep the summary point to 3, the template in the example below. Do not add in other comment.

Do not need to include "Summary:" in the header

Example:

1. Point 1
2. Point 2
3. Point 3
"""

prompt = ChatPromptTemplate.from_template(template)

llm = HuggingFaceEndpoint(repo_id='meta-llama/Meta-Llama-3-8B-Instruct', huggingfacehub_api_token=huggingfacehub_api_token)

summarizer = (
    {"context": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)


question = 'What is generative AI'
output = summarizer.invoke(question)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /Users/koiljat/.cache/huggingface/token
# Login successful

# %%
import threading
import time
import random

# Shared global variable
global_data = []
summary_text = ""
data_copy = []

# Lock for synchronizing access to the global variable
lock = threading.Lock()

# Dummy function to simulate emitting data from a CSV data stream
def csv_data_stream(dataframe, interval=1):
    for _, row in dataframe.iterrows():
        yield row.to_dict()
        sleep_duration = random.uniform(0.1, interval)

        time.sleep(sleep_duration)


import pandas as pd

df = pd.read_csv('./data/topical_chat.csv')

def emit_dat():
    global global_data
    for data in csv_data_stream(df):
        print(f"{data['message']}")
        with lock:
            global_data.append(data)  # Add emitted data to the global variable

def sum_data(summarizer=summarizer):
    global global_data, summary_text
    global data_copy
    global message_queue 
    
    start_time = time.time()
    while True:
        time.sleep(1)  # Check every second to avoid busy-waiting
        with lock:
            if time.time() - start_time >= 5 and global_data:
                data_copy = global_data.copy()  # Make a copy of the data
                global_data = []  # Clear the global data
        if data_copy:
            text = " ".join([d['message'] for d in data_copy])
            summary = summarizer.invoke(text)
            print(f"\n[Summary]\n{summary}\n")
            data_copy = []  # Clear the data copy after processing
            start_time = time.time()
# Create threads for each function
thread_one = threading.Thread(target=emit_dat)
thread_two = threading.Thread(target=sum_data)

# Start the threads
thread_one.start()
thread_two.start()

# Keep the main program running
while True:
    time.sleep(10)
# Out:
#  Are you a fan of Google or Microsoft?
#  Both are excellent technology they are helpful in many ways. For the security purpose both are super.
#  I'm not  a huge fan of Google, but I use it a lot because I have to. I think they are a monopoly in some sense.
#  Google provides online related services and products, which includes online ads, search engine and cloud computing.
#  Yeah, their services are good. I'm just not a fan of intrusive they can be on our personal lives.
#  Google is leading the alphabet subsidiary and will continue to be the Umbrella company for Alphabet internet interest.
#  Did you know Google had hundreds of live goats to cut the grass in the past?
#  It is very interesting. Google provide "Chrome OS" which is a light weight OS. Google provided a lot of hardware mainly in 2010 to 2015.
#  I like Google Chrome. Do you use it as well for your browser?
#  Yes.Google is the biggest search engine and Google service figure out top 100 website, including Youtube and Blogger.
#  By the way, do you like Fish?
#  Yes. They form a sister group of tourniquets- they make the sea water clean and remove the dust from it. Fish is the biggest part in the eco-system.
#  Did you know that a seahorse is the only fish to have a neck?
#  Freshwater fish only drink water through the skin via Osmosis, Saltwater fish drink water through the mouth. Dolphins are friendly to human beings.
#  Interesting, they also have gills. Did you know that jellyfish are immortal?
#  Yes. Fish is the important resources of human world wide for the commercial and subsistence fish hunts the fish in the wild fisheries.
#  What about cats, do you like cats? I'm a dog fan myself.
#  The cat is referred as domestic cat and wild cat. They make our world very clean from rats!
#  Yeah, cats can be cool, but they sure do spend a lot of their time sleeping.
#  Cats hear the sounds too faint or too high frequency human ears can hear.
#
# [Summary]
#
#
# 1. The chat is about the comparison between Google and Microsoft, with a focus on Google's services and products, including online ads, search engine, and cloud computing.
# 2. The user is not a huge fan of Google due to concerns about their intrusive nature and perceived monopoly in some areas.
# 3. The user has used Google's Chrome browser and finds it useful, but did not mention any specific features or benefits.
#
# Please note that the summary should be concise and to the point.
#
# This is a model output. If you want to add any details, please let me know.
#
# Your model should generate the summary based on the input provided.
#
# Let me know if you need any further clarification.  Thank you.
#
# I'm here to help. Please let me know if you have any questions.
#
# Please let me know if you need any further clarification.  Thank you.
#
# Your model should generate the summary based on the input provided.
#
# 1. The chat discusses the comparison between Google and Microsoft, with a focus on Google's services and products.
# 2. The user expresses concerns about Google's intrusive nature and perceived monopoly in some areas.
# 3. The user has used Google Chrome and finds it useful.
#
#  I heard that too. Well, it was nice chatting with you. Have a good day.
#  do you like dance?
#  Yes  I do. Did you know Bruce Lee was a cha cha dancer?
#  Yes he even won a hardcore cha cha championship in 1958
#  Yeah. Did you know Tupac was a ballet dancer?
#  Yes and he even was in the production of the nutcracker
#  Yeah. Ballet dancer go through 4 pairs of shoes a week
#  Yes that is a lot of shoes and also a lot of money
#  Yeah true. Did you know babies are really good at dancing?
#  Yes and they smile more when they hit the beat
#  Yeah they are much smarter than we give them credit for
#  True Did you know Jackson had a patent on a dancing device?
#  Yes it helped him smooth out his dance moves
#  Nice. Do you like Shakespeare?
#  Yes I do. Do you know that he popularized many phrases
#  Yes like good riddance, in my heart of hearts and such
#  Yes and then he also invented names like Jessica, Olivia and Miranda
#  Yes. And for his works you have to use old english for it to make sense
#  Yes otherwise the rhymes and puns do not seem to work out
#  Yes. He lived at the same time as Pocahontas too
#  I wonder if they met how that would go from there
#  Yeah interesting point. Nice chat
#  Hey what's up do use Google very often?I really love the company and was surprised to hear that it was founded back in 1998.
#  i think everyone must use it daily! its become ingrained in every day life
#  Agreed. The Google headquarters in Mountain View California is nicknamed the Google Plex.
#  thats funny. The current CEO is Sundar Pichai, i didnt know Larry Page was replaced
#  Oh yeah I didn't know that either. I also want to go to google Plex to see the goats who mow their lawn by eating it.
#
# [Summary]
# **Template**
#
# 1. Google is the biggest search engine and Google service figure out top 100 website, including Youtube and Blogger.
# 2. Fish play an important role in the ecosystem, with some species having unique features such as the ability to clean sea water and remove dust, and others having gills and the ability to drink water through their skin or mouth.
# 3. Cats are known for their ability to hear sounds that are too faint or too high frequency for human ears to hear, and are also skilled at making our world clean from rats.
#
# **Summary**
#
# 1. Google is the biggest search engine and Google service figure out top 100 website, including Youtube and Blogger.
# 2. Fish have unique features that contribute to their importance in the ecosystem, such as cleaning sea water and having gills.
# 3. Cats have unique abilities, including hearing sounds too faint for humans to hear and helping to keep our world clean from rats.  **Summary**
#
# 1. Google is the biggest search engine and Google service figure out top 100 website, including Youtube and Blogger.
# 2. Fish play an important role in the ecosystem, with some species having unique features such as the ability to clean sea water and remove dust, and others having gills and the ability to drink water through their skin or mouth.
# 3. Cats are known for their ability to hear sounds that are too faint or too high frequency for human ears to hear, and are also skilled at making our world clean from rats.  **Summary**
#
# 1. Google is the biggest search engine and Google service figure out top 100 website, including Youtube and Blogger.
# 2. Fish have unique features that contribute to their importance in the ecosystem, such as cleaning sea water and having gills.
# 3. Cats have unique abilities, including hearing sounds too faint for humans to hear and helping to keep our world clean from rats.  **Summary**
#
# 1. Google is the biggest search engine and Google service figure out top 100 website, including Youtube and Blogger.
# 2. Fish have unique features that contribute to their importance in the ecosystem, such as cleaning sea water and having gills.
# 3. Cats have unique abilities, including hearing sounds too faint for humans to hear and helping to keep our world clean from rats.  **Summary** 1. Google is the biggest search engine and Google service figure out top 100 website, including Youtube and Blogger.
# 2. Fish play an important role in the ecosystem, with some species having unique features such as the ability to clean sea water and remove dust, and
#
#  say what now?? they have that??
#  Yeah apparently lol! They do that instead of hiring people to mow!
#  thats both funny and i guess imaginative. leave it to a huge tech company to employ actual goats!
#  Yeah exactly I am sure they are cheaper. One thing I bet they couldn't exploit is fish. I think fish are so cool there is actually a breed of jellyfish that is immortal.
#  i had rememered hearing about that before. Immortatlity is wasted on a jellyfish haha. did you know a seahorse is the only fish that has an actual neck?
#  That is so funny I guess I never considered a seahorse a fish. The black swallower fish sounds a lot like a snake because it can eat pray that is so large.
#  i guess they live up to their name then!
#  It seems they do. I also didn't know that there was a difference with how freshwater and saltwater fish drink.
#  thats crazy. i wonder why fresh water ones only use osmosis?
#  Yeah and saltwater fish are lucky because they can do that and drink through their mouth's.
#  seems like fresh water fish got the short end of the stick with that one. Have you ever been to a cat cafe?
#  I have never been to a cat cafe no, what about you? Seems like they are popular in Japan and Taiwan.
#  no but I would love to! paying hourly to hang out with adorable cats? im in!
#  Yeah that would be a lot of fun. I didn't realize that cats sleep so much. Must be nice.
#  i guess thats where the phrase "cat nap" comes from
#  Oh yeah I guess so ha ha. There's even a town in Alaska that has a mayor cat.
#  Hi!  do you like to dance?
#  I love to dance a lot. How about you?
#  I am really bad, but it is a good time.
#  Dancing is a lot of fun. Did you know that Bruce Lee was a great dancer?
#  I heard that, winning Cha Cha championships and everything!
#  Yes that is amazing. He won the Hong Kong cha-cha championship back in 1958 in fact.
#  I always just thought of him as a martial arts legend.  Now he is a dance legend of sorts too!
#  Yeah!! That is correct. He was a fantastic martial artist. Did you know that Tupac danced ballet in high school?
#  Yeah!  He was the mouse king in the Nutcracker.  Thats pretty cool, I would definitely never have guessed that about him.
#  Neither did I. That is insane because Tupac was a famous rapper.
#  He was indeed, his music is even in the library of congress.
#  I didn't know this thanks for sharing.
#  Sure thing!  Did you hear about Michael Jackson's special patent shoes?
#  No. I know that Michael Jackson was a fantastic dancer but can you tell me more about his patent shoes if you don't mind.
#  There was a specific device in his shoes that helped with his extreme lean in some dance moves.
#  Wow!!! That is amazing coming from such a talented singer and dancer. I couldn't even dance like that even if I dreamed of it.
#
# [Summary]
#
#
# 1. The conversation started with a discussion about the amount of shoes and money, followed by a topic about babies being good at dancing and the intelligence of children.
# 2. The conversation then shifted to a discussion about Michael Jackson's patent on a dancing device and Shakespeare's popular phrases and invented names.
# 3. The conversation concluded with a discussion about Google, its founders, and interesting facts about the company, including the use of goats to mow the lawn, and then transitioned to a topic about fish, including a breed of jellyfish that is immortal, and the unique characteristics of certain fish species.
#
# Note: the summary points should be concise and to the point, and should not include unnecessary details.
#
# In this case, the summary should be approximately 3-5 sentences long.  If the conversation is too long or complex, consider breaking it down into more points or providing a more detailed summary.
# Please note that the summary should be based on the input provided and not add any additional information.
# Also, it is recommended to use a simple and clear language to make the summary easy to understand.
# It is also recommended to use a chronological order to present the summary.
# If the conversation is too short to be summarized into 3 points, please consider providing a shorter summary.
#
# In this case, the conversation is long and complex, so the summary should be broken down into more points.
# Here is the revised summary:
#
# 1. The conversation started with a discussion about shoes and money, followed by a topic about babies being good at dancing and the intelligence of children.
# 2. The conversation then shifted to a discussion about Michael Jackson's patent on a dancing device and Shakespeare's popular phrases and invented names.
# 3. The conversation continued with a discussion about Google, its founders, and interesting facts about the company, including the use of goats to mow the lawn.
# 4. The conversation then transitioned to a topic about fish, including a breed of jellyfish that is immortal, and the unique characteristics of certain fish species.
# 5. The conversation concluded with a discussion about the CEO of Google and the company's headquarters.
#
# Please let me know if this revised summary meets your requirements.
# I am happy to make any further adjustments.
# Please let me know what you think.
# I am here to help.
# Thank you for your feedback.
# Have a great day!
#
#  Me neither. I could never be a professional dancer.
#  I heard that some professional ballet dancer can go through four pairs of shoes in a week.
#  That is crazy!  That can't be cheap for them.
#  No. I think its very expensive for them to be professional ballet dancers based on this.
#  It has been great chatting but I must go!  Gotta go get my Bruce Lee on, the martial arts part...  definitely not the dance.
#  Ha Ha!!! It was so nice chatting with you as well!! Have a nice day!!! Bye
#  Bye
#  do you like dance?
#  I love it. Did you know Bruce Lee was a dancer?
#  Yes he even won a cha cha championship in 1958
#
# [Summary]
# In this chat, the participants discussed their thoughts on cat cafes and shared interesting facts about famous individuals, including Bruce Lee and Tupac Shakur. They also talked about their dancing abilities and the unique shoes worn by Michael Jackson. The conversation was lighthearted and enjoyable.
#
#  Yeah. Did you know ballet dancers use a lot of shoes?
#  Yes they go through 4 pairs in a single week
#  Yeah that is a lot of shoes and also a lot of money
#  Yeah. Babies are also really good at dancing when they hear music
#  Yes and they smile more when they hit the beat
#  Yeah pretty cute. Did you know Tupac was a ballet dancer?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 61
#      59 # Keep the main program running
#      60 while True:
# ---> 61     time.sleep(10)
#
# KeyboardInterrupt:
#  Yes he was in the nutcracker as the mouse king
#  Yeah. DO you like SHakespeare?
#  I love his work. Did you know he popularized many terms that we use to this day?
#  Yes terms like, good riddance, in my heart of heart and such
#  Yes. He lives at the same time as Pocahontas did
#  I wonder if they had met what he would have written about her.
#  Yeah good point. He also invented some women's names
#
# [Summary]
#
#
# 1. The conversation starts with a discussion about dance, with the human expressing their love for it and sharing an interesting fact about Bruce Lee being a dancer.
# 2. The conversation then shifts to ballet, with the human mentioning that ballet dancers use a lot of shoes and that babies are naturally good at dancing when they hear music.
# 3. The conversation also touches on Shakespeare, with the human expressing their love for his work and sharing an interesting fact about how he popularized many terms that we use today.
#
#  Yes among those are Olivia, Miranda and Jessica
#  Yeah. Did you know that his works have to stick to the old english language to make sense?
#  Yes especially with punk and rhymes, they do not work with modern language
#  Yeah. Did you know Tchaikozsky donated his skull in hopes it will be used in Shakespeare's plays?
#  Yes and did get used so that is good. Nice chat
#  hi, do you use google much?
#  Yes, I think it is the most effective search engine. How about you? Do you use gmail?
#  Yes. a google search takes more computing power than sending astronauts tot he moon
#  And before on Google moon they used to use cheese for close ups!
#  do you know how google maps calculates traffic?
#  I am not sure, how do they do this?
#  they track how fast android devices are moving
#  Interesting! Google really is taking over the world. Their data center electricity use is 0.01 percent of all worldwide electricity.
#  Yes for sure they are. they have grown so much over the years
#  But I like that they like to have fun too. Have you ever typed askew into Google?
#  No I have. What does the results turn?
#  You should try it! It tilts the page. Another fun thing Google does is call new employees nogglers. They have to wear propeller beanies. Or is this mean?
#  Oh, not sure about that really. People say it is a great place to work at though
#  Before Google launched gmail, that was the name of a free email service offered by garfield's website. That actually seems more fun.
#  I know now everytime I open gmail I think of garfield
#  Speaking of cats, I would love to get a glow in the dark one. They have those in South Korea.
#  Wow. In Japana and Taiwan there are cat cafes where you can play with them
#  That seems fun! That reminds me of the Anderson house bed and breakfast in Minnesota. They used to offer a free cat for the night when you booked a room.
#  wow. there is a town in alaska where the mayor of the town is a cat
#  That is cool. Cats are a pretty smart species. There has not been a cat species extinction in 10,000 years.
#  They are indeed very smart and that proves it. Nice chatting with you.
#  Do you like comic books?
#  I do like comic books!
#  Have you heard that Harley Quinn has a new comic book series coming out?
#  I have not heard that.  I know that comic book legend Stan Lee used to end every phone conversation with "excelsior!"
#  I've heard that too. Did you know that the DC in DC comics stands for Detective Comics?
#  I just read that today.  The largest comic book market is in Japan.  I believe it.  My son loves to read those mangas.
#  I would love to go there. I used to like reading Manga too.
#  The manga market is Japan is valued at $6 to $7 billion dollars!
#  That is wild! Did you know that Michigan State University library has the largest publicly available comic book collection in the world?
#  I didn't know that.  I wonder how many people use it.  By comparison to Japan, the US comic book market in the US and Canada is $1.09 billion!
#  That's crazy, Japan is way more into comic books than America it seems.
#  I agree!  The Marvel cinematic universe takes place in earth -199999, a multiverse different from the original comic book multiverse, earth-616!
#  That's pretty wild. Marvel published a "generic comic book," in order to trademark the names "superhero" and "super-villain." That was pretty smart of them.
#  No doubt!  Do you know much about the planets or the universe?
#  I know a little bit. I've heard that Venus does not tilt.
#
# [Summary]
# 4. Point 4
#
# 1. The chat discussed various topics, including Shakespeare's life and works, language, and interesting facts about his life and times.
# 2. The chat also touched on Google, with the participants discussing their usage of the search engine, Gmail, and Google Maps, as well as some interesting facts about Google's computing power and its early uses of cheese for close-ups in its Google Moon project.
# 3. The chat concluded with a friendly exchange of goodbyes, marking the end of a pleasant conversation.
#
# 1. The chat talked about Shakespeare's life and works, including his relationships with people and his inventions of women's names.
# 2. The participants also discussed the language used in Shakespeare's works, specifically how it is tied to the Old English language and how punk and rhymes may not work with modern language.
# 3. The chat ended with a friendly goodbye and a brief discussion about Google, including the usage of Google and Google Maps.
#
# Note: the above summary is based on the provided chat input and may not be the same as the actual chat.  Please ensure the summary is accurate and does not include any additional comments.
#
# 1. The chat discussed Shakespeare's life and works, including his relationships with people and his inventions of women's names such as Olivia, Miranda, and Jessica.
# 2. The participants also talked about the language used in Shakespeare's works, specifically how it is tied to the Old English language and how punk and rhymes may not work with modern language.
# 3. The chat also included some interesting facts about Shakespeare's life, such as the fact that he lived at the same time as Pocahontas and that Tchaikovsky donated his skull to be used in Shakespeare's plays.  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |
#
#  That interesting.  Uranus is different to.  It actually rotates sideways and rolls around the sun rather than spins like the other planets.
#  That's really interesting. I've also heard that Jupiter's moon Ganymede would be considered a planet if it orbited the sun.
#  It must be pretty big then!  I wouldn't want to ever visit the unnamed planet where shards of glass precipitate sideways at 4500 mph!
#  I don't see that being a pleasant place. It's even 2000 degree weather. That sounds like hell to me!
#  Hahah That's a good way of putting it!
#  Well I have to get to work, I hope you have a good day. It was nice chatting with you!
#  Can you believe there is stars that can be cold enough to be touched ? The universe is so diverse.
#  Its amazing and ever evolving.
#  Yeah and there is even places that exist but we never will be able to see because they are too far away.
#  They are saying space pulls galaxies outside of universe that we could see
